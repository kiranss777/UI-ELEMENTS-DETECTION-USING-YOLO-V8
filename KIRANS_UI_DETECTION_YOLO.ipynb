# %% [markdown]
# Candidate Name: Kiran SS
# Phno: 9880194078
# email: kiranss458@gmail.com
# github: https://github.com/kiranss777

# %% [markdown]
# I have Used YOLOv8 for the task and for the dataset i have used an annotated adn labelled dataset which was readily available on roboflow websit

# %%
# !nvidia-smi
# Out:
# Wed Jan  3 05:47:56 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 6.6 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source="https://ultralytics.com/images/bus.jpg"
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 228.0ms
# Speed: 4.0ms preprocess, 228.0ms inference, 920.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pwd
# Out:
# /content

# %%
# !pip install ultralytics==8.0.20
from IPython import display
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/UIDATA
# Out:
# /content/drive/MyDrive/UIDATA

# %%
# !ls
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# %cd /content/drive/MyDrive/UIDATA
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 plots=True
# Out:
# /content/drive/MyDrive/UIDATA
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# LISTING EVERYTHING IN THE train4 FORLDER ie the EVALUATION METRICS AND RESULTS

# %%
# !ls runs/detect/train4
# Out:
# args.yaml					    results.png		   val_batch0_pred.jpg
# confusion_matrix.png				    train_batch0.jpg	   val_batch1_labels.jpg
# events.out.tfevents.1704272869.079d140d70a7.5846.0  train_batch1560.jpg    val_batch1_pred.jpg
# F1_curve.png					    train_batch1561.jpg    val_batch2_labels.jpg
# P_curve.png					    train_batch1562.jpg    val_batch2_pred.jpg
# PR_curve.png					    train_batch1.jpg	   weights
# R_curve.png					    train_batch2.jpg
# results.csv					    val_batch0_labels.jpg

# %%
from IPython.display import Image

# %%
Image(filename='/content/drive/MyDrive/UIDATA/runs/detect/train4/results.png')

# %%
Image(filename='/content/drive/MyDrive/UIDATA/runs/detect/train4/val_batch0_pred.jpg')

# %%
Image(filename='/content/drive/MyDrive/UIDATA/runs/detect/train4/val_batch2_pred.jpg')

# %% [markdown]
# TEST THE TRAINED MODEL

# %%
# !yolo task=detect mode=predict model=runs/detect/train4/weights/best.pt data=data.yaml epochs=2 conf=0.25 source=/content/drive/MyDrive/UIDATA/test/images/761_png.rf.c75be2b488331e5afe4d2fd4e056f7df.jpg
# Out:
# 2024-01-03 11:08:56.281484: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-03 11:08:56.281535: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-03 11:08:56.282879: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-03 11:08:57.324232: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11131002 parameters, 0 gradients, 28.5 GFLOPs
# ...

# %%
Image(filename='/content/drive/MyDrive/UIDATA/runs/detect/train10/train_batch2.jpg')
